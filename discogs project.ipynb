# %%
import pandas as pd
import requests
#!pip install git+https://github.com/grigorjevas/Discogs-marketplace-scraper

    
###https://github.com/grigorjevas/Discogs-marketplace-scraper

# %%
import pandas as pd
import re

# %%
# from discogs import scraper
# scraper = scraper.DiscogsMarketplaceScraper("new wave", 1000)
# df = scraper.fetch_items

## scrapped sample of 1000

# %%
combined_df = pd.DataFrame()

# %%
# Import the necessary libraries
import pandas as pd
from discogs import scraper

### scrape generes separatly as they are not going in a loop - gets an error

scraper = scraper.DiscogsMarketplaceScraper("hip hop", 1000)
dfhiphop = scraper.fetch_items


##  ["new wave","experimental", "house", "ambient", "fusion", "folk", "funk", "industrial", "thrash"]
# Out:
# Processing item 1/1000: https://www.discogs.com/sell/item/2462180078
# Processing item 2/1000: https://www.discogs.com/sell/item/2465209967
# Processing item 3/1000: https://www.discogs.com/sell/item/2468924288
# Processing item 4/1000: https://www.discogs.com/sell/item/2413873310
# Processing item 5/1000: https://www.discogs.com/sell/item/2460915815
# Processing item 6/1000: https://www.discogs.com/sell/item/2489552738
# Processing item 7/1000: https://www.discogs.com/sell/item/2389337734
# Processing item 8/1000: https://www.discogs.com/sell/item/2470625984
# Processing item 9/1000: https://www.discogs.com/sell/item/2495698526
# Processing item 10/1000: https://www.discogs.com/sell/item/2411926781
# Processing item 11/1000: https://www.discogs.com/sell/item/2484805154
# Processing item 12/1000: https://www.discogs.com/sell/item/2494322705
# Processing item 13/1000: https://www.discogs.com/sell/item/2295521452
# Processing item 14/1000: https://www.discogs.com/sell/item/2483355548
# ...

# %%
dfhiphop["genre"] = "hip hop"

combined_df = pd.concat([combined_df, dfhiphop], ignore_index=True)

# %%
# Import the necessary libraries
import pandas as pd
from discogs import scraper

scraper = scraper.DiscogsMarketplaceScraper("new wave", 1000)
dfNW= scraper.fetch_items

##  ["experimental", "house", "ambient", "fusion", "folk", "funk", "industrial", "thrash"]
# Out:
# Processing item 1/1000: https://www.discogs.com/sell/item/2497485710
# Processing item 2/1000: https://www.discogs.com/sell/item/2482226138
# Processing item 3/1000: https://www.discogs.com/sell/item/2300310031
# Processing item 4/1000: https://www.discogs.com/sell/item/2295185344
# Processing item 5/1000: https://www.discogs.com/sell/item/2312169172
# Processing item 6/1000: https://www.discogs.com/sell/item/2384062216
# Processing item 7/1000: https://www.discogs.com/sell/item/2299350454
# Processing item 8/1000: https://www.discogs.com/sell/item/2434044860
# Processing item 9/1000: https://www.discogs.com/sell/item/2312339209
# Processing item 10/1000: https://www.discogs.com/sell/item/2312445121
# Processing item 11/1000: https://www.discogs.com/sell/item/2300313040
# Processing item 12/1000: https://www.discogs.com/sell/item/2300312968
# Processing item 13/1000: https://www.discogs.com/sell/item/2299350439
# Processing item 14/1000: https://www.discogs.com/sell/item/2295184663
# ...

# %%
dfNW["genre"] = "new wave"

combined_df = pd.concat([combined_df, dfNW], ignore_index=True)

# %%
# Import the necessary libraries
import pandas as pd
from discogs import scraper

### scrape generes separatly as they are not going in a loop - gets an error


scraper = scraper.DiscogsMarketplaceScraper("experimental", 1000)
dfexperimental= scraper.fetch_items

##  ["experimental", "house", "ambient", "fusion", "folk", "funk", "industrial", "thrash"]
# Out:
# Processing item 1/1000: https://www.discogs.com/sell/item/1713331537
# Processing item 2/1000: https://www.discogs.com/sell/item/2411918240
# Processing item 3/1000: https://www.discogs.com/sell/item/1713349564
# Processing item 4/1000: https://www.discogs.com/sell/item/2491301264
# Processing item 5/1000: https://www.discogs.com/sell/item/2490906269
# Processing item 6/1000: https://www.discogs.com/sell/item/2490900506
# Processing item 7/1000: https://www.discogs.com/sell/item/2490901103
# Processing item 8/1000: https://www.discogs.com/sell/item/2490882707
# Processing item 9/1000: https://www.discogs.com/sell/item/2490882770
# Processing item 10/1000: https://www.discogs.com/sell/item/2490883022
# Processing item 11/1000: https://www.discogs.com/sell/item/2490883121
# Processing item 12/1000: https://www.discogs.com/sell/item/2450695103
# Processing item 13/1000: https://www.discogs.com/sell/item/1933128719
# Processing item 14/1000: https://www.discogs.com/sell/item/1942699967
# ...

# %%
dfexperimental["genre"] = "experimental"

combined_df = pd.concat([combined_df, dfexperimental], ignore_index=True)

# %%
# Import the necessary libraries
import pandas as pd
from discogs import scraper

### scrape generes separatly as they are not going in a loop - gets an error


scraper = scraper.DiscogsMarketplaceScraper("house", 1000)
dfhouse= scraper.fetch_items

##  ["house", "ambient", "fusion", "folk", "funk", "industrial", "thrash"]
# Out:
# Processing item 1/1000: https://www.discogs.com/sell/item/2468623049
# Processing item 2/1000: https://www.discogs.com/sell/item/1411387189
# Processing item 3/1000: https://www.discogs.com/sell/item/1028090947
# Processing item 4/1000: https://www.discogs.com/sell/item/1033653517
# Processing item 5/1000: https://www.discogs.com/sell/item/1190641120
# Processing item 6/1000: https://www.discogs.com/sell/item/891185888
# Processing item 7/1000: https://www.discogs.com/sell/item/1287639588
# Processing item 8/1000: https://www.discogs.com/sell/item/1247360751
# Processing item 9/1000: https://www.discogs.com/sell/item/799869101
# Processing item 10/1000: https://www.discogs.com/sell/item/1334295484
# Processing item 11/1000: https://www.discogs.com/sell/item/840647627
# Processing item 12/1000: https://www.discogs.com/sell/item/655888756
# Processing item 13/1000: https://www.discogs.com/sell/item/765442712
# Processing item 14/1000: https://www.discogs.com/sell/item/1368865522
# ...

# %%
dfhouse["genre"] = "house"

combined_df = pd.concat([combined_df, dfhouse], ignore_index=True)

# %%
# Import the necessary libraries
import pandas as pd
from discogs import scraper

### scrape generes separatly as they are not going in a loop - gets an error


scraper = scraper.DiscogsMarketplaceScraper("ambient", 1000)
dfambient= scraper.fetch_items

##  ["fusion", "folk", "funk", "industrial", "thrash"]
# Out:
# Processing item 1/1000: https://www.discogs.com/sell/item/2497510301
# Processing item 2/1000: https://www.discogs.com/sell/item/1981233155
# Processing item 3/1000: https://www.discogs.com/sell/item/1783072498
# Processing item 4/1000: https://www.discogs.com/sell/item/2497509515
# Processing item 5/1000: https://www.discogs.com/sell/item/1869843877
# Processing item 6/1000: https://www.discogs.com/sell/item/1559810038
# Processing item 7/1000: https://www.discogs.com/sell/item/1410712657
# Processing item 8/1000: https://www.discogs.com/sell/item/2088832781
# Processing item 9/1000: https://www.discogs.com/sell/item/1777199077
# Processing item 10/1000: https://www.discogs.com/sell/item/2118869786
# Processing item 11/1000: https://www.discogs.com/sell/item/1251971580
# Processing item 12/1000: https://www.discogs.com/sell/item/2255723026
# Processing item 13/1000: https://www.discogs.com/sell/item/2495669705
# Processing item 14/1000: https://www.discogs.com/sell/item/2279423986
# ...

# %%
dfambient["genre"] = "ambient"

combined_df = pd.concat([combined_df, dfambient], ignore_index=True)

# %%
# Import the necessary libraries
import pandas as pd
from discogs import scraper

### scrape generes separatly as they are not going in a loop - gets an error


scraper = scraper.DiscogsMarketplaceScraper("fusion", 1000)
dffusion= scraper.fetch_items

##  [ "folk", "funk", "industrial", "thrash"]
# Out:
# Processing item 1/1000: https://www.discogs.com/sell/item/2003931197
# Processing item 2/1000: https://www.discogs.com/sell/item/2445942749
# Processing item 3/1000: https://www.discogs.com/sell/item/2269193011
# Processing item 4/1000: https://www.discogs.com/sell/item/2299252405
# Processing item 5/1000: https://www.discogs.com/sell/item/2299252309
# Processing item 6/1000: https://www.discogs.com/sell/item/2431259081
# Processing item 7/1000: https://www.discogs.com/sell/item/2172397100
# Processing item 8/1000: https://www.discogs.com/sell/item/2104848083
# Processing item 9/1000: https://www.discogs.com/sell/item/2301286237
# Processing item 10/1000: https://www.discogs.com/sell/item/2470614752
# Processing item 11/1000: https://www.discogs.com/sell/item/1979701832
# Processing item 12/1000: https://www.discogs.com/sell/item/2010526937
# Processing item 13/1000: https://www.discogs.com/sell/item/2294901976
# Processing item 14/1000: https://www.discogs.com/sell/item/2003285702
# ...

# %%
dffusion["genre"] = "fusion"

combined_df = pd.concat([combined_df, dffusion], ignore_index=True)

# %%
# Import the necessary libraries
import pandas as pd
from discogs import scraper                                   
### scrape generes separatly as they are not going in a loop - gets an error

scraper = scraper.DiscogsMarketplaceScraper("funk", 1000)
dffunk= scraper.fetch_items

##  ["industrial", "thrash"]
# Out:
# Processing item 1/1000: https://www.discogs.com/sell/item/348662494
# Processing item 2/1000: https://www.discogs.com/sell/item/421497892
# Processing item 3/1000: https://www.discogs.com/sell/item/414492990
# Processing item 4/1000: https://www.discogs.com/sell/item/352458020
# Processing item 5/1000: https://www.discogs.com/sell/item/409022290
# Processing item 6/1000: https://www.discogs.com/sell/item/390680520
# Processing item 7/1000: https://www.discogs.com/sell/item/408988522
# Processing item 8/1000: https://www.discogs.com/sell/item/414493107
# Processing item 9/1000: https://www.discogs.com/sell/item/2497523237
# Processing item 10/1000: https://www.discogs.com/sell/item/2497522682
# Processing item 11/1000: https://www.discogs.com/sell/item/2497522493
# Processing item 12/1000: https://www.discogs.com/sell/item/2252852620
# Processing item 13/1000: https://www.discogs.com/sell/item/1844885680
# Processing item 14/1000: https://www.discogs.com/sell/item/1844885206
# ...

# %%
dffunk["genre"] = "funk"

combined_df = pd.concat([combined_df, dffunk], ignore_index=True)

# %%
combined_df
# Out:
#                                     artist                     title  \
# 0                                Tom Misch               Beat Tape 2
# 1                        Lous & The Yakuza                      IOTA
# 2     Grandmaster Flash & The Furious Five               The Message
# 3                            $hit & $hine*             New Confusion
# 4                             Theo Parrish  DJ-Kicks Detroit Forward
# ...                                    ...                       ...
# 6993                           France Joli                   Tonight
# 6994                   Bobby Boyd Congress        The Sun Is Shining
# 6995                     Kenny Moore Meets           Love Is The Key
# 6996                    Brass Construction     Ha Cha Cha (Funktion)
# 6997                      Paul Johnson (2)                  Personal
#
#                                                   label release_format  \
# ...

# %%
# Import the necessary libraries
import pandas as pd
from discogs import scraper

### scrape generes separatly as they are not going in a loop - gets an error


scraper = scraper.DiscogsMarketplaceScraper("thrash", 1000)
dfthrash= scraper.fetch_items

##  [ "thrash"]
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3452\3528936319.py in <module>
#       7
#       8 scraper = scraper.DiscogsMarketplaceScraper("thrash", 1000)
# ----> 9 dfthrash= scraper.fetch_items
#      10
# ...

# %%
dfthrash["genre"] = "thrash"

### scrape generes separatly as they are not going in a loop - gets an error


combined_df = pd.concat([combined_df, dfthrash], ignore_index=True)

# %%
## save the the scraped to a combined DF 

combined_df.to_csv('preclean.csv', index=False)

# %%
combined_df
# Out:
#                                     artist                     title  \
# 0                                Tom Misch               Beat Tape 2
# 1                        Lous & The Yakuza                      IOTA
# 2     Grandmaster Flash & The Furious Five               The Message
# 3                            $hit & $hine*             New Confusion
# 4                             Theo Parrish  DJ-Kicks Detroit Forward
# ...                                    ...                       ...
# 6993                           France Joli                   Tonight
# 6994                   Bobby Boyd Congress        The Sun Is Shining
# 6995                     Kenny Moore Meets           Love Is The Key
# 6996                    Brass Construction     Ha Cha Cha (Funktion)
# 6997                      Paul Johnson (2)                  Personal
#
#                                                   label release_format  \
# ...

# %%
df= pd.read_csv('preclean.csv')

# %%
df.isnull().sum()
# Out:
# artist                0
# title                 0
# label                 0
# release_format        0
# number_of_tracks      0
# release_date        203
# price                 0
# rating              257
# votes               257
# have                  0
# want                  0
# limited_edition       0
# media_condition       0
# sleeve_condition      0
# release_page          0
# genre                 0
# dtype: int64

# %%
df['release_date'].value_counts(dropna=False)
# Out:
# NaN            203
# 1989           194
# 1988           193
# 1987           175
# 1990           158
#               ...
# 12 Jan 2011      1
# 07 Feb 2023      1
# 15 Aug 2016      1
# 13 May 2016      1
# 25 Feb 2013      1
# Name: release_date, Length: 1590, dtype: int64

# %%
df_nan_rows = df[df['release_date'].isnull()]

print(df_nan_rows)
# Out:
#                                          artist  \
# 87                         Nuf-El-Tee Featuring
# 190                                  Space Lady
# 216                           Double Or Nothin'
# 371                                   DJ Phatty
# 442                        The Party People (4)
# ...                                         ...
# 6809                            Electric Safari
# 6883  Lonnie Liston Smith And The Cosmic Echoes
# 6908                            The Magic Touch
# 6920                                        War
# 6943                                Isaac Hayes
#
#                                 title                          label  \
# 87                Back Together Again               Retro ‎– RET 128
# 190   Boom Bap Girl / The Gift Pt. II            G.A.M.M. ‎– GAMM029
# 216                        Invincible      Cupid Records ‎– CUP-1402
# 371         Volume 1 (Le Rockshow 01)   Not On Label ‎– PHATTY VOL 1
# ...

# %%
df["release_date"]
# Out:
# 0       25 Mar 2016
# 1              2022
# 2       20 Jan 2023
# 3       28 Oct 2022
# 4       28 Oct 2022
#            ...
# 6993           1980
# 6994           1972
# 6995           1989
# 6996           1976
# 6997           1989
# Name: release_date, Length: 6998, dtype: object

# %%
import numpy as np
import pandas as pd
### extract only year from "release_date"
years = []

for date in df["release_date"]:
    year = ""
    # check for NaN values
    if isinstance(date, float) and np.isnan(date):
        year = "Unknown"
    # handle different date formats
    elif isinstance(date, str):
        try:
            year = pd.to_datetime(date).year
        except ValueError:
            # handle other date formats here
            pass
    years.append(year)

# %%
years
# Out:
# [2016,
#  2022,
#  2023,
#  2022,
#  2022,
#  2022,
#  2023,
#  2023,
#  2022,
#  2022,
#  2010,
#  2022,
#  2022,
#  2020,
#  2020,
#  2020,
#  2019,
#  2020,
#  2020,
#  2020,
#  2019,
#  2019,
#  2019,
#  2011,
#  2015,
#  2015,
#  2014,
#  2013,
#  2018,
#  2022,
#  2018,
#  2021,
#  2022,
#  2021,
#  2019,
#  2022,
#  2022,
#  2017,
#  2016,
#  2016,
#  2016,
#  2016,
#  1991,
#  1988,
#  1989,
#  2017,
#  1988,
#  2019,
#  1999,
#  1988,
#  2011,
#  2008,
#  2020,
#  2006,
#  2018,
#  1995,
#  2014,
#  2012,
#  2005,
#  2005,
#  2014,
#  1996,
#  2014,
#  2012,
#  2004,
#  2011,
#  2018,
#  2020,
#  2016,
#  2011,
#  2022,
#  2020,
#  2020,
#  2019,
#  2015,
#  1990,
#  1990,
#  1998,
#  1990,
#  1985,
#  1998,
#  1989,
#  1992,
#  1997,
#  1989,
#  1999,
#  1990,
#  'Unknown',
#  1989,
#  1983,
#  1993,
#  1986,
#  1986,
#  2004,
#  1991,
#  1988,
#  1991,
#  1993,
#  1991,
#  1988,
#  1989,
#  2000,
#  1989,
#  1997,
#  1991,
#  1989,
#  1988,
#  1993,
#  1990,
#  1987,
# ...

# %%
## add df['year'] to dataframe 
df['year']=years

# %%
##df["release_date"]

# %%
##df[["day", "month", "year"]] = df["release_date"].str.split(" ", expand = True)
### split release date to day month and year

# %%
#check values and nulls 

df.year.value_counts(dropna=False)
# Out:
# 2022    437
# 2019    319
# 2017    288
# 2018    283
# 2021    240
#        ...
# 1966      1
# 1964      1
# 1963      1
# 1962      1
# 1961      1
# Name: year, Length: 63, dtype: int64

# %%
##df['year'] = df['year'].fillna(df['day'])

# %%
##df

# %%
##df=df.drop(columns=['day'])

# %%
df
# Out:
#                                     artist                     title  \
# 0                                Tom Misch               Beat Tape 2
# 1                        Lous & The Yakuza                      IOTA
# 2     Grandmaster Flash & The Furious Five               The Message
# 3                            $hit & $hine*             New Confusion
# 4                             Theo Parrish  DJ-Kicks Detroit Forward
# ...                                    ...                       ...
# 6993                           France Joli                   Tonight
# 6994                   Bobby Boyd Congress        The Sun Is Shining
# 6995                     Kenny Moore Meets           Love Is The Key
# 6996                    Brass Construction     Ha Cha Cha (Funktion)
# 6997                      Paul Johnson (2)                  Personal
#
#                                                   label release_format  \
# ...

# %%
##df=df.drop(columns=['month'])

# %%
## should all be ok , drop release date 
df=df.drop(columns=['release_date'])

# %%
df
# Out:
#                                     artist                     title  \
# 0                                Tom Misch               Beat Tape 2
# 1                        Lous & The Yakuza                      IOTA
# 2     Grandmaster Flash & The Furious Five               The Message
# 3                            $hit & $hine*             New Confusion
# 4                             Theo Parrish  DJ-Kicks Detroit Forward
# ...                                    ...                       ...
# 6993                           France Joli                   Tonight
# 6994                   Bobby Boyd Congress        The Sun Is Shining
# 6995                     Kenny Moore Meets           Love Is The Key
# 6996                    Brass Construction     Ha Cha Cha (Funktion)
# 6997                      Paul Johnson (2)                  Personal
#
#                                                   label release_format  \
# ...

# %%
# Function to extract text from a brackets in column

def extract_text(row):
    pattern = r"\((.*?)\)"
    match = re.search(pattern, row)
    if match:
        return match.group(1)
    else:
        return ""

# %%
import re

## extract from brakets in column "media_condition" might end up with blank value will fill out with null or with no cover 
df["media_condition"] = df["media_condition"].apply(extract_text)

# %%
df

# %%
## split if there is "or" in the value and take only first word

df["media_condition"]=df["media_condition"].str.split("or").str[0]

# %%
## extract from brakets in column "sleeve_condition" might end up with blank value will fill out with null or with no cover 

df["sleeve_condition"] = df["sleeve_condition"].apply(extract_text)

# %%
## split if there is "or" in the value and take only first word


df["sleeve_condition"]=df["sleeve_condition"].str.split("or").str[0]

# %%
df.head(1000)
# Out:
#                                    artist                        title  \
# 0                               Tom Misch                  Beat Tape 2
# 1                       Lous & The Yakuza                         IOTA
# 2    Grandmaster Flash & The Furious Five                  The Message
# 3                           $hit & $hine*                New Confusion
# 4                            Theo Parrish     DJ-Kicks Detroit Forward
# ..                                    ...                          ...
# 995                           Soul Scream             蝶と蜂 / 7つの敵/7つの味方
# 996                 MC Miker G. & DJ Sven                  Holiday Rap
# 997                            S.P.C. (2)  Skill Plus Creativity Vol.1
# 998                            Mariko Ide                     風と共にながれて
# 999                           Petey Pablo           Get Me Out Of Jail
#
#                                                  label release_format  \
# ...

# %%
## split between label name and label code , might drop label code as it will be unique 

df1=df 
df1[["label_name", "label_code"]] = df1["label"].str.extract(r'(.*?)–(.*)')
# Remove leading/trailing whitespaces in the label name and code columns
df1["label_name"] = df1["label_name"].str.strip()
df1["label_code"] = df1["label_code"].str.strip()
# Drop the original "label" column
df1 = df1.drop("label", axis=1)
# Drop duplicates based on the "label_name" column
##df1 = df1.drop_duplicates()

# %%
## should it be ok at this point, save the dataframe and continue cleaning and model in the next notebook 
df1
# Out:
#                                     artist                     title  \
# 0                                Tom Misch               Beat Tape 2
# 1                        Lous & The Yakuza                      IOTA
# 2     Grandmaster Flash & The Furious Five               The Message
# 3                            $hit & $hine*             New Confusion
# 4                             Theo Parrish  DJ-Kicks Detroit Forward
# ...                                    ...                       ...
# 6993                           France Joli                   Tonight
# 6994                   Bobby Boyd Congress        The Sun Is Shining
# 6995                     Kenny Moore Meets           Love Is The Key
# 6996                    Brass Construction     Ha Cha Cha (Funktion)
# 6997                      Paul Johnson (2)                  Personal
#
#      release_format  number_of_tracks  price  rating  votes  have  want  \
# ...

# %%
## save function 

df1.to_csv('Final-Project.csv', index=False)

# %%
## check nulls and see it is same in the next notebook 
df1.isnull().sum()
# Out:
# artist                0
# title                 0
# release_format        0
# number_of_tracks      0
# price                 0
# rating              257
# votes               257
# have                  0
# want                  0
# limited_edition       0
# media_condition       0
# sleeve_condition      0
# release_page          0
# genre                 0
# year                  0
# label_name            0
# label_code            0
# dtype: int64

# %%
#### dont touch any more !

# %%
df_empty_rows = df[df['sleeve_condition'].str.strip() == '']

print(df_empty_rows)

# %%
df
