# %%
import pandas as pd
import requests
# !pip install git+https://github.com/grigorjevas/Discogs-marketplace-scraper

    
###https://github.com/grigorjevas/Discogs-marketplace-scraper
# Out:
# Collecting git+https://github.com/grigorjevas/Discogs-marketplace-scraper
#   Cloning https://github.com/grigorjevas/Discogs-marketplace-scraper to c:\users\adyto\appdata\local\temp\pip-req-build-gdft2tgq
#   Resolved https://github.com/grigorjevas/Discogs-marketplace-scraper to commit f50632fd95c6f3efe9ab87f1f904555115f3f518
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: asttokens==2.0.4 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (2.0.4)
# Requirement already satisfied: attrs==20.3.0 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (20.3.0)
# Requirement already satisfied: beautifulsoup4==4.9.3 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (4.9.3)
# Requirement already satisfied: certifi==2020.12.5 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (2020.12.5)
# Requirement already satisfied: chardet==4.0.0 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (4.0.0)
# Requirement already satisfied: colorama==0.4.4 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (0.4.4)
# Requirement already satisfied: executing==0.5.4 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (0.5.4)
# Requirement already satisfied: icecream==2.1.0 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (2.1.0)
# Requirement already satisfied: idna==2.10 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (2.10)
# Requirement already satisfied: iniconfig==1.1.1 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (1.1.1)
# Requirement already satisfied: numpy==1.20.1 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (1.20.1)
# Requirement already satisfied: packaging==20.9 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (20.9)
# Requirement already satisfied: pandas==1.2.3 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (1.2.3)
# Requirement already satisfied: pluggy==0.13.1 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (0.13.1)
# Requirement already satisfied: py==1.10.0 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (1.10.0)
# Requirement already satisfied: Pygments==2.8.1 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (2.8.1)
# Requirement already satisfied: pyparsing==2.4.7 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (2.4.7)
# Requirement already satisfied: pytest==6.2.2 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (6.2.2)
# Requirement already satisfied: python-dateutil==2.8.1 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (2.8.1)
# Requirement already satisfied: pytz==2021.1 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (2021.1)
# Requirement already satisfied: requests==2.25.1 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (2.25.1)
# Requirement already satisfied: six==1.15.0 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (1.15.0)
# Requirement already satisfied: soupsieve==2.2 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (2.2)
# Requirement already satisfied: toml==0.10.2 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (0.10.2)
# Requirement already satisfied: urllib3==1.26.3 in c:\users\adyto\anaconda3\lib\site-packages (from discogs-marketplace-scraper==0.0.1) (1.26.3)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\adyto\anaconda3\lib\site-packages (from pytest==6.2.2->discogs-marketplace-scraper==0.0.1) (1.4.0)
#   Running command git clone --filter=blob:none --quiet https://github.com/grigorjevas/Discogs-marketplace-scraper 'C:\Users\adyto\AppData\Local\Temp\pip-req-build-gdft2tgq'

# %%
import pandas as pd
import re

# %%
from discogs import scraper
scraper = scraper.DiscogsMarketplaceScraper("new wave", 10)
df = scraper.fetch_items

## scrapped sample of 10
# Out:
# Processing item 1/10: https://www.discogs.com/sell/item/2482665539
# Processing item 2/10: https://www.discogs.com/sell/item/2482665329
# Processing item 3/10: https://www.discogs.com/sell/item/2482665311
# Processing item 4/10: https://www.discogs.com/sell/item/2435751461
# Processing item 5/10: https://www.discogs.com/sell/item/2475524099
# Processing item 6/10: https://www.discogs.com/sell/item/2435600225
# Processing item 7/10: https://www.discogs.com/sell/item/2141393966
# Processing item 8/10: https://www.discogs.com/sell/item/2482664342
# Processing item 9/10: https://www.discogs.com/sell/item/2482664198
# Processing item 10/10: https://www.discogs.com/sell/item/1171534317

# %%
df["release_date"]
# Out:
# 0       Jun 1986
# 1           2020
# 2           1987
# 3    27 Aug 2021
# 4    31 Jul 2020
# 5    25 Sep 2020
# 6    27 Mar 2020
# 7    15 Jun 2020
# 8           1983
# 9           1991
# Name: release_date, dtype: object

# %%
df
# Out:
#                  artist                                              title  \
# 0            The B-52's                                         The B-52's
# 1                  a-ha                               Hunting High And Low
# 2  Graziella De Michele                               Cathy Prend Le Train
# 3  Water From Your Eyes                                          Structure
# 4          Karger Traum                                                III
# 5      Marie Davidson &                                 Renegade Breakdown
# 6         Молчат Дома =                                     Этажи = Etazhi
# 7             En Direct                                  A Shattered Frame
# 8               Various  Fast Times At Ridgemont High • Music From The ...
# 9         Pascal Bellut                             De Passage/Je M'Endors
#
#                                                label release_format  \
# 0                        Island Records ‎– ILPM 9580             LP
# 1  Warner Records ‎– R1 25300, Warner Records ‎– ...             LP
# 2                                    Virgin ‎– 80333            12"
# 3                       Wharf Cat Records ‎– WCR 122             LP
# 4     DKA Records ‎– DKA022, Fixed Rhythms ‎– FRS008             LP
# 5                               Ninja Tune ‎– ZEN267             LP
# 6                   Sacred Bones Records ‎– SBR-3037             LP
# 7                              Lunatic Rec. ‎– LUN07            12"
# 8                       WEA ‎– 99246, WEA ‎– K 99246             LP
# 9                             Not On Label ‎– PB 001             7"
#
#    number_of_tracks release_date  price rating votes have want  \
# 0                 9     Jun 1986  24.99   4.29    68  774  314
# 1                10         2020  28.00   4.36    66  736  137
# 2                 3         1987   2.99   3.40     5   41    4
# 3                 8  27 Aug 2021  20.00   5.00     2   50    8
# 4                10  31 Jul 2020  16.00   5.00     7   35   18
# 5                10  25 Sep 2020  22.00   4.60    10  102   63
# 6                 9  27 Mar 2020  60.00   4.79    61  604  778
# 7                 5  15 Jun 2020  11.95   4.71     7   78   41
# 8                10         1983   5.71   3.88     8  139   28
# 9                 2         1991  24.99   4.00     2    2   15
#
#    limited_edition                                    media_condition  \
# 0                0  Very Good Plus (VG+) Will show some signs that...
# 1                0  Mint (M) Absolutely perfect in every way. Cert...
# 2                0  Near Mint (NM or M-) A nearly perfect record. ...
# 3                0  Near Mint (NM or M-) A nearly perfect record. ...
# 4                0  Near Mint (NM or M-) A nearly perfect record. ...
# 5                1  Near Mint (NM or M-) A nearly perfect record. ...
# 6                1  Near Mint (NM or M-) A nearly perfect record. ...
# 7                1  Mint (M) Absolutely perfect in every way. Cert...
# 8                0  Very Good Plus (VG+) Will show some signs that...
# 9                0  Very Good Plus (VG+) Will show some signs that...
#
#        sleeve_condition                                       release_page
# 0        Very Good (VG)  https://discogs.com/release/600930-The-B-52s-T...
# 1              Mint (M)  https://discogs.com/release/15496411-a-ha-Hunt...
# 2  Near Mint (NM or M-)  https://discogs.com/release/3750159-Graziella-...
# 3  Near Mint (NM or M-)  https://discogs.com/release/21939475-Water-Fro...
# 4  Near Mint (NM or M-)  https://discogs.com/release/15858373-Karger-Tr...
# 5  Near Mint (NM or M-)  https://discogs.com/release/15964023-Marie-Dav...
# 6  Near Mint (NM or M-)  https://discogs.com/release/14987446-%D0%9C%D0...
# 7              Mint (M)  https://discogs.com/release/15428803-En-Direct...
# 8        Very Good (VG)  https://discogs.com/release/4197226-Various-Fa...
# 9  Very Good Plus (VG+)  https://discogs.com/release/12578963-Pascal-Be...

# %%
df[["day", "month", "year"]] = df["release_date"].str.split(" ", expand = True)

# %%
df['year'] = df['year'].fillna(df['day'])

# %%
df=df.drop(columns=['month', 'day'])

# %%
df=df.drop(columns=['release_date'])

# %%
df
# Out:
#                  artist                                              title  \
# 0            The B-52's                                         The B-52's
# 1                  a-ha                               Hunting High And Low
# 2  Graziella De Michele                               Cathy Prend Le Train
# 3  Water From Your Eyes                                          Structure
# 4          Karger Traum                                                III
# 5      Marie Davidson &                                 Renegade Breakdown
# 6         Молчат Дома =                                     Этажи = Etazhi
# 7             En Direct                                  A Shattered Frame
# 8               Various  Fast Times At Ridgemont High • Music From The ...
# 9         Pascal Bellut                             De Passage/Je M'Endors
#
#                                                label release_format  \
# 0                        Island Records ‎– ILPM 9580             LP
# 1  Warner Records ‎– R1 25300, Warner Records ‎– ...             LP
# 2                                    Virgin ‎– 80333            12"
# 3                       Wharf Cat Records ‎– WCR 122             LP
# 4     DKA Records ‎– DKA022, Fixed Rhythms ‎– FRS008             LP
# 5                               Ninja Tune ‎– ZEN267             LP
# 6                   Sacred Bones Records ‎– SBR-3037             LP
# 7                              Lunatic Rec. ‎– LUN07            12"
# 8                       WEA ‎– 99246, WEA ‎– K 99246             LP
# 9                             Not On Label ‎– PB 001             7"
#
#    number_of_tracks  price rating votes have want  limited_edition  \
# 0                 9  24.99   4.29    68  774  314                0
# 1                10  28.00   4.36    66  736  137                0
# 2                 3   2.99   3.40     5   41    4                0
# 3                 8  20.00   5.00     2   50    8                0
# 4                10  16.00   5.00     7   35   18                0
# 5                10  22.00   4.60    10  102   63                1
# 6                 9  60.00   4.79    61  604  778                1
# 7                 5  11.95   4.71     7   78   41                1
# 8                10   5.71   3.88     8  139   28                0
# 9                 2  24.99   4.00     2    2   15                0
#
#                                      media_condition      sleeve_condition  \
# 0  Very Good Plus (VG+) Will show some signs that...        Very Good (VG)
# 1  Mint (M) Absolutely perfect in every way. Cert...              Mint (M)
# 2  Near Mint (NM or M-) A nearly perfect record. ...  Near Mint (NM or M-)
# 3  Near Mint (NM or M-) A nearly perfect record. ...  Near Mint (NM or M-)
# 4  Near Mint (NM or M-) A nearly perfect record. ...  Near Mint (NM or M-)
# 5  Near Mint (NM or M-) A nearly perfect record. ...  Near Mint (NM or M-)
# 6  Near Mint (NM or M-) A nearly perfect record. ...  Near Mint (NM or M-)
# 7  Mint (M) Absolutely perfect in every way. Cert...              Mint (M)
# 8  Very Good Plus (VG+) Will show some signs that...        Very Good (VG)
# 9  Very Good Plus (VG+) Will show some signs that...  Very Good Plus (VG+)
#
#                                         release_page  year
# 0  https://discogs.com/release/600930-The-B-52s-T...   Jun
# 1  https://discogs.com/release/15496411-a-ha-Hunt...  2020
# 2  https://discogs.com/release/3750159-Graziella-...  1987
# 3  https://discogs.com/release/21939475-Water-Fro...  2021
# 4  https://discogs.com/release/15858373-Karger-Tr...  2020
# 5  https://discogs.com/release/15964023-Marie-Dav...  2020
# 6  https://discogs.com/release/14987446-%D0%9C%D0...  2020
# 7  https://discogs.com/release/15428803-En-Direct...  2020
# 8  https://discogs.com/release/4197226-Various-Fa...  1983
# 9  https://discogs.com/release/12578963-Pascal-Be...  1991

# %%
# Function to extract text from a row
def extract_text(row):
    pattern = r"\((.*?)\)"
    match = re.search(pattern, row)
    if match:
        return match.group(1)
    else:
        return ""

# %%
df["media_condition"] = df["media_condition"].apply(extract_text)
df["sleeve_condition"] = df["sleeve_condition"].apply(extract_text)

# %%
df["media_condition"]=df["media_condition"].str.split("or").str[0]

# %%
df["sleeve_condition"]=df["sleeve_condition"].str.split("or").str[0]

# %%
df
# Out:
#                  artist                                              title  \
# 0            The B-52's                                         The B-52's
# 1                  a-ha                               Hunting High And Low
# 2  Graziella De Michele                               Cathy Prend Le Train
# 3  Water From Your Eyes                                          Structure
# 4          Karger Traum                                                III
# 5      Marie Davidson &                                 Renegade Breakdown
# 6         Молчат Дома =                                     Этажи = Etazhi
# 7             En Direct                                  A Shattered Frame
# 8               Various  Fast Times At Ridgemont High • Music From The ...
# 9         Pascal Bellut                             De Passage/Je M'Endors
#
#                                                label release_format  \
# 0                        Island Records ‎– ILPM 9580             LP
# 1  Warner Records ‎– R1 25300, Warner Records ‎– ...             LP
# 2                                    Virgin ‎– 80333            12"
# 3                       Wharf Cat Records ‎– WCR 122             LP
# 4     DKA Records ‎– DKA022, Fixed Rhythms ‎– FRS008             LP
# 5                               Ninja Tune ‎– ZEN267             LP
# 6                   Sacred Bones Records ‎– SBR-3037             LP
# 7                              Lunatic Rec. ‎– LUN07            12"
# 8                       WEA ‎– 99246, WEA ‎– K 99246             LP
# 9                             Not On Label ‎– PB 001             7"
#
#    number_of_tracks  price rating votes have want  limited_edition  \
# 0                 9  24.99   4.29    68  774  314                0
# 1                10  28.00   4.36    66  736  137                0
# 2                 3   2.99   3.40     5   41    4                0
# 3                 8  20.00   5.00     2   50    8                0
# 4                10  16.00   5.00     7   35   18                0
# 5                10  22.00   4.60    10  102   63                1
# 6                 9  60.00   4.79    61  604  778                1
# 7                 5  11.95   4.71     7   78   41                1
# 8                10   5.71   3.88     8  139   28                0
# 9                 2  24.99   4.00     2    2   15                0
#
#   media_condition sleeve_condition  \
# 0             VG+               VG
# 1               M                M
# 2             NM               NM
# 3             NM               NM
# 4             NM               NM
# 5             NM               NM
# 6             NM               NM
# 7               M                M
# 8             VG+               VG
# 9             VG+              VG+
#
#                                         release_page  year
# 0  https://discogs.com/release/600930-The-B-52s-T...   Jun
# 1  https://discogs.com/release/15496411-a-ha-Hunt...  2020
# 2  https://discogs.com/release/3750159-Graziella-...  1987
# 3  https://discogs.com/release/21939475-Water-Fro...  2021
# 4  https://discogs.com/release/15858373-Karger-Tr...  2020
# 5  https://discogs.com/release/15964023-Marie-Dav...  2020
# 6  https://discogs.com/release/14987446-%D0%9C%D0...  2020
# 7  https://discogs.com/release/15428803-En-Direct...  2020
# 8  https://discogs.com/release/4197226-Various-Fa...  1983
# 9  https://discogs.com/release/12578963-Pascal-Be...  1991

# %%
df1=df 
df1[["label_name", "label_code"]] = df1["label"].str.extract(r'(.*?)–(.*)')
# Remove leading/trailing whitespaces in the label name and code columns
df1["label_name"] = df1["label_name"].str.strip()
df1["label_code"] = df1["label_code"].str.strip()
# Drop the original "label" column
df1 = df1.drop("label", axis=1)
# Drop duplicates based on the "label_name" column
df1 = df1.drop_duplicates(subset="label_name")

# %%
df1
# Out:
#                  artist                                              title  \
# 0            The B-52's                                         The B-52's
# 1                  a-ha                               Hunting High And Low
# 2  Graziella De Michele                               Cathy Prend Le Train
# 3  Water From Your Eyes                                          Structure
# 4          Karger Traum                                                III
# 5      Marie Davidson &                                 Renegade Breakdown
# 6         Молчат Дома =                                     Этажи = Etazhi
# 7             En Direct                                  A Shattered Frame
# 8               Various  Fast Times At Ridgemont High • Music From The ...
# 9         Pascal Bellut                             De Passage/Je M'Endors
#
#   release_format  number_of_tracks  price rating votes have want  \
# 0             LP                 9  24.99   4.29    68  774  314
# 1             LP                10  28.00   4.36    66  736  137
# 2            12"                 3   2.99   3.40     5   41    4
# 3             LP                 8  20.00   5.00     2   50    8
# 4             LP                10  16.00   5.00     7   35   18
# 5             LP                10  22.00   4.60    10  102   63
# 6             LP                 9  60.00   4.79    61  604  778
# 7            12"                 5  11.95   4.71     7   78   41
# 8             LP                10   5.71   3.88     8  139   28
# 9             7"                 2  24.99   4.00     2    2   15
#
#    limited_edition media_condition sleeve_condition  \
# 0                0             VG+               VG
# 1                0               M                M
# 2                0             NM               NM
# 3                0             NM               NM
# 4                0             NM               NM
# 5                1             NM               NM
# 6                1             NM               NM
# 7                1               M                M
# 8                0             VG+               VG
# 9                0             VG+              VG+
#
#                                         release_page  year  \
# 0  https://discogs.com/release/600930-The-B-52s-T...   Jun
# 1  https://discogs.com/release/15496411-a-ha-Hunt...  2020
# 2  https://discogs.com/release/3750159-Graziella-...  1987
# 3  https://discogs.com/release/21939475-Water-Fro...  2021
# 4  https://discogs.com/release/15858373-Karger-Tr...  2020
# 5  https://discogs.com/release/15964023-Marie-Dav...  2020
# 6  https://discogs.com/release/14987446-%D0%9C%D0...  2020
# 7  https://discogs.com/release/15428803-En-Direct...  2020
# 8  https://discogs.com/release/4197226-Various-Fa...  1983
# 9  https://discogs.com/release/12578963-Pascal-Be...  1991
#
#                label_name                                label_code
# 0        Island Records ‎                                 ILPM 9580
# 1        Warner Records ‎  R1 25300, Warner Records ‎– 081227954680
# 2                Virgin ‎                                     80333
# 3     Wharf Cat Records ‎                                   WCR 122
# 4           DKA Records ‎           DKA022, Fixed Rhythms ‎– FRS008
# 5            Ninja Tune ‎                                    ZEN267
# 6  Sacred Bones Records ‎                                  SBR-3037
# 7          Lunatic Rec. ‎                                     LUN07
# 8                   WEA ‎                     99246, WEA ‎– K 99246
# 9          Not On Label ‎                                    PB 001
